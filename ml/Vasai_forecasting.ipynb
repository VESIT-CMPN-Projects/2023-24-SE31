# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("./data/market/Vasai.Rice.csv")
df['Price Date'] = pd.to_datetime(df['Price Date'], format='%d %b %Y').dt.strftime('%Y-%m-%d')
df.drop(['Min Price (Rs./Quintal)','Max Price (Rs./Quintal)',], axis=1, inplace = True)
df.rename(columns={'Modal Price (Rs./Quintal)':'Price', 'Price Date': 'Date'}, inplace = True)
df.set_index('Date', inplace = True)
df.sort_index(inplace = True)
df.index = pd.to_datetime(df.index)
df
# Out:
#             Price
# Date
# 2004-12-29   1450
# 2005-01-09    630
# 2005-01-10    630
# 2005-01-13    725
# 2005-01-17   1300
# ...           ...
# 2024-02-14   3790
# 2024-02-16   3860
# 2024-02-19   3425
# 2024-02-21   3450
# 2024-02-22   3850
#
# [2440 rows x 1 columns]

# %%
df = df.resample('D').first()

df['Price'].interpolate(method='pchip', inplace=True)
df
# Out:
# /tmp/ipykernel_13107/3950296218.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price'].interpolate(method='pchip', inplace=True)
#                   Price
# Date
# 2004-12-29  1450.000000
# 2004-12-30  1312.819935
# 2004-12-31  1187.242675
# 2005-01-01  1073.576258
# 2005-01-02   972.128725
# ...                 ...
# 2024-02-18  3537.777778
# 2024-02-19  3425.000000
# 2024-02-20  3430.733083
# 2024-02-21  3450.000000
# 2024-02-22  3850.000000
#
# [6995 rows x 1 columns]

# %%
df
# Out:
#                   Price
# Date
# 2004-12-29  1450.000000
# 2004-12-30  1312.819935
# 2004-12-31  1187.242675
# 2005-01-01  1073.576258
# 2005-01-02   972.128725
# ...                 ...
# 2024-02-18  3537.777778
# 2024-02-19  3425.000000
# 2024-02-20  3430.733083
# 2024-02-21  3450.000000
# 2024-02-22  3850.000000
#
# [6995 rows x 1 columns]

# %%
df.describe().transpose()
# Out:
#         count         mean         std    min          25%          50%  \
# Price  6995.0  2458.242533  873.435324  630.0  1653.399699  2504.095128
#
#           75%     max
# Price  3150.0  4490.0

# %%
print(df['Price'].min())
# Out:
# 630.0

# %%
print(df['Price'].min())
# Out:
# 630.0

# %%
df.plot(figsize=(20, 4))
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(df, model="multiplicative")

# %%
result.resid.plot(figsize=(8, 5))
plt.ylabel("Price Deviation")
plt.show()

# %%
PREDICTION_DAYS = 28

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# %%
sequence_length = 56

# %%
X, y = [], []

sequences = []

for i in range(len(df) - sequence_length):
    X.append(scaled_data[i:(i + sequence_length)])
    y.append(scaled_data[(i + sequence_length)][0])

X = np.array(X)
y = np.array(y)

# %%
X.shape, y.shape
# Out:
# ((6939, 56, 1), (6939,))

# %%
split = int(0.8 * len(X))

# %%
X_train, X_val = X[:split], X[split:]
y_train, y_val = y[:split], y[split:]

# %%
X_train.shape
y_train.shape
# Out:
# (5551,)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

model = Sequential(
    [
        LSTM(units=64, return_sequences=True, activation="relu", input_shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(units=64, return_sequences=False),
        Dense(units=1),
    ]
)

model.compile(optimizer="adam", loss="mean_squared_error")
# Out:
# 2024-03-27 20:03:16.305341: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-27 20:03:16.367329: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-27 20:03:16.367402: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-27 20:03:16.369301: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-27 20:03:16.378798: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-27 20:03:16.379736: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-27 20:03:17.670320: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 56, 64)            16896
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 49985 (195.25 KB)
# Trainable params: 49985 (195.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=28, epochs=50, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 199/199 [==============================] - 9s 32ms/step - loss: 0.0060 - val_loss: 0.0020
# Epoch 2/50
# 199/199 [==============================] - 6s 29ms/step - loss: 8.0297e-04 - val_loss: 0.0019
# Epoch 3/50
# 199/199 [==============================] - 6s 29ms/step - loss: 7.7512e-04 - val_loss: 0.0019
# Epoch 4/50
# 199/199 [==============================] - 6s 30ms/step - loss: 7.4304e-04 - val_loss: 0.0018
# Epoch 5/50
# 199/199 [==============================] - 6s 29ms/step - loss: 7.4943e-04 - val_loss: 0.0018
# Epoch 6/50
# 199/199 [==============================] - 6s 29ms/step - loss: 7.1596e-04 - val_loss: 0.0025
# Epoch 7/50
# 199/199 [==============================] - 6s 29ms/step - loss: 6.7580e-04 - val_loss: 0.0019
# Epoch 8/50
# 199/199 [==============================] - 6s 29ms/step - loss: 6.6678e-04 - val_loss: 0.0017
# Epoch 9/50
# 199/199 [==============================] - 6s 29ms/step - loss: 6.4893e-04 - val_loss: 0.0019
# Epoch 10/50
# 199/199 [==============================] - 6s 29ms/step - loss: 6.2361e-04 - val_loss: 0.0019
# Epoch 11/50
# 199/199 [==============================] - 6s 29ms/step - loss: 6.3391e-04 - val_loss: 0.0016
# Epoch 12/50
# 199/199 [==============================] - 6s 29ms/step - loss: 6.0210e-04 - val_loss: 0.0018
# Epoch 13/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.9061e-04 - val_loss: 0.0017
# Epoch 14/50
# 199/199 [==============================] - 6s 29ms/step - loss: 6.0822e-04 - val_loss: 0.0015
# Epoch 15/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.5377e-04 - val_loss: 0.0015
# Epoch 16/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.5027e-04 - val_loss: 0.0015
# Epoch 17/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.5083e-04 - val_loss: 0.0014
# Epoch 18/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.5040e-04 - val_loss: 0.0017
# Epoch 19/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.4259e-04 - val_loss: 0.0018
# Epoch 20/50
# 199/199 [==============================] - 6s 30ms/step - loss: 5.6730e-04 - val_loss: 0.0014
# Epoch 21/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.2821e-04 - val_loss: 0.0013
# Epoch 22/50
# 199/199 [==============================] - 6s 31ms/step - loss: 5.2825e-04 - val_loss: 0.0015
# Epoch 23/50
# 199/199 [==============================] - 6s 30ms/step - loss: 5.4195e-04 - val_loss: 0.0013
# Epoch 24/50
# 199/199 [==============================] - 6s 32ms/step - loss: 5.1893e-04 - val_loss: 0.0018
# Epoch 25/50
# 199/199 [==============================] - 6s 30ms/step - loss: 5.0809e-04 - val_loss: 0.0018
# Epoch 26/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.4212e-04 - val_loss: 0.0014
# Epoch 27/50
# 199/199 [==============================] - 7s 33ms/step - loss: 5.3044e-04 - val_loss: 0.0014
# Epoch 28/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.0739e-04 - val_loss: 0.0013
# Epoch 29/50
# 199/199 [==============================] - 6s 30ms/step - loss: 4.9324e-04 - val_loss: 0.0014
# Epoch 30/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.6557e-04 - val_loss: 0.0013
# Epoch 31/50
# 199/199 [==============================] - 6s 30ms/step - loss: 5.2403e-04 - val_loss: 0.0013
# Epoch 32/50
# 199/199 [==============================] - 6s 30ms/step - loss: 5.2659e-04 - val_loss: 0.0015
# Epoch 33/50
# 199/199 [==============================] - 7s 33ms/step - loss: 5.4640e-04 - val_loss: 0.0014
# Epoch 34/50
# 199/199 [==============================] - 7s 34ms/step - loss: 5.0627e-04 - val_loss: 0.0015
# Epoch 35/50
# 199/199 [==============================] - 6s 31ms/step - loss: 5.1012e-04 - val_loss: 0.0015
# Epoch 36/50
# 199/199 [==============================] - 7s 37ms/step - loss: 4.9139e-04 - val_loss: 0.0014
# Epoch 37/50
# 199/199 [==============================] - 7s 33ms/step - loss: 5.6226e-04 - val_loss: 0.0017
# Epoch 38/50
# 199/199 [==============================] - 6s 31ms/step - loss: 5.1727e-04 - val_loss: 0.0014
# Epoch 39/50
# 199/199 [==============================] - 7s 34ms/step - loss: 4.9867e-04 - val_loss: 0.0013
# Epoch 40/50
# 199/199 [==============================] - 6s 30ms/step - loss: 5.2808e-04 - val_loss: 0.0013
# Epoch 41/50
# 199/199 [==============================] - 6s 30ms/step - loss: 5.0294e-04 - val_loss: 0.0014
# Epoch 42/50
# 199/199 [==============================] - 6s 30ms/step - loss: 5.0984e-04 - val_loss: 0.0014
# Epoch 43/50
# 199/199 [==============================] - 6s 30ms/step - loss: 4.8801e-04 - val_loss: 0.0015
# Epoch 44/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.3395e-04 - val_loss: 0.0013
# Epoch 45/50
# 199/199 [==============================] - 6s 29ms/step - loss: 4.9314e-04 - val_loss: 0.0015
# Epoch 46/50
# 199/199 [==============================] - 6s 30ms/step - loss: 4.9400e-04 - val_loss: 0.0015
# Epoch 47/50
# 199/199 [==============================] - 6s 30ms/step - loss: 4.9556e-04 - val_loss: 0.0013
# Epoch 48/50
# 199/199 [==============================] - 6s 30ms/step - loss: 4.9303e-04 - val_loss: 0.0015
# Epoch 49/50
# 199/199 [==============================] - 6s 29ms/step - loss: 5.3350e-04 - val_loss: 0.0014
# Epoch 50/50
# 199/199 [==============================] - 6s 30ms/step - loss: 5.1704e-04 - val_loss: 0.0013

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])

# %%
from joblib import dump, load

# %%
from sklearn.pipeline import Pipeline

dump(
    Pipeline([("scaler", scaler), ("model", model)]), "./out/forecast.LSTM.Vasai.joblib"
)
# Out:
# ['./out/forecast.LSTM.Vasai.joblib']

# %%
x_test = scaled_data[-sequence_length:]
x_test = np.array([x_test])

# %%
x_test.shape
# Out:
# (1, 56, 1)

# %%
predictions = model.predict(X)
# Out:
# 217/217 [==============================] - 3s 11ms/step

# %%
predictions = predictions.reshape(-1,1)
predictions = scaler.inverse_transform(predictions).flatten()

# %%
from datetime import timedelta

# %%
future_dates = [df.index[-1] + timedelta(days=i) for i in range(1, 29)]

# %%
plt.figure(figsize=(20, 4))
plt.plot(df.index[-300:], df['Price'][-300:], label='Original Data', c="#666666")
plt.plot(df.index[-sequence_length-300:-sequence_length], predictions[-300:], label='Predicted Prices', c="#00000088")
plt.title('Time Series Forecasting with LSTM')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

(
    mean_absolute_error(predictions, df["Price"][sequence_length:]),
    mean_squared_error(predictions, df["Price"][sequence_length:], squared=False),
)
# Out:
# /home/smv/code/fresh-fields/venv/lib/python3.11/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (54.51882268824429, 96.6448841195712)
